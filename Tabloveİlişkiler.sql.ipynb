-- %% [markdown]
-- # [dbo].[Adresler]

-- %%
USE [HayvanMagazas]
GO

-- %%
/****** Object:  Table [dbo].[Adresler]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Adresler](
	[adres_id] [int] NOT NULL,
	[musteri_id] [int] NOT NULL,
	[adres_detayi] [varchar](100) NULL,
	[sehir] [varchar](50) NULL,
	[posta_kodu] [varchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[adres_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Calisanlar]

-- %%
/****** Object:  Table [dbo].[Calisanlar]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Calisanlar](
	[calisan_id] [int] NOT NULL,
	[calisan_adi] [varchar](50) NOT NULL,
	[calisan_tel] [varchar](15) NULL,
	[calisan_maas] [decimal](10, 2) NULL,
	[komisyon] [decimal](5, 2) NULL,
	[ise_baslama_tarihi] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[calisan_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CalisanPerformansi]

-- %%
/****** Object:  Table [dbo].[CalisanPerformansi]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CalisanPerformansi](
	[performans_id] [int] NOT NULL,
	[calisan_id] [int] NOT NULL,
	[siparis_id] [int] NOT NULL,
	[komisyon_tutar] [decimal](10, 2) NULL,
	[performans_tarihi] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[performans_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[IadeIslemleri]

-- %%
/****** Object:  Table [dbo].[IadeIslemleri]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[IadeIslemleri](
	[iade_id] [int] NOT NULL,
	[siparis_id] [int] NOT NULL,
	[urun_id] [int] NOT NULL,
	[iade_tarihi] [datetime] NULL,
	[iade_sebebi] [varchar](100) NULL,
	[iade_durumu] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[iade_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Kargo]

-- %%
/****** Object:  Table [dbo].[Kargo]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Kargo](
	[kargo_id] [int] NOT NULL,
	[siparis_id] [int] NOT NULL,
	[kargo_durumu] [varchar](50) NULL,
	[kargo_takip_no] [varchar](20) NULL,
	[kargo_tarih] [datetime] NULL,
	[teslim_tarihi] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[kargo_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Kategori]

-- %%
/****** Object:  Table [dbo].[Kategori]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Kategori](
	[kategori_id] [int] NOT NULL,
	[kategori_adi] [varchar](50) NOT NULL,
	[ust_kategori_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[kategori_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Musteriler]

-- %%
/****** Object:  Table [dbo].[Musteriler]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Musteriler](
	[musteri_id] [int] NOT NULL,
	[musteri_adi] [varchar](50) NOT NULL,
	[musteri_telefon_no] [varchar](15) NULL,
	[kayit_tarihi] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[musteri_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SiparisDetay]

-- %%
/****** Object:  Table [dbo].[SiparisDetay]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SiparisDetay](
	[siparis_detay_id] [int] NOT NULL,
	[siparis_id] [int] NOT NULL,
	[urun_id] [int] NOT NULL,
	[urun_sayisi] [int] NOT NULL,
	[birim_fiyat] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[siparis_detay_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Siparisler]

-- %%
/****** Object:  Table [dbo].[Siparisler]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Siparisler](
	[siparis_id] [int] IDENTITY(1,1) NOT NULL,
	[musteri_id] [int] NOT NULL,
	[calisan_id] [int] NOT NULL,
	[siparis_tarihi] [datetime] NULL,
	[toplam_fiyat] [decimal](10, 2) NULL,
	[siparis_durumu] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[siparis_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tedarikciler]

-- %%
/****** Object:  Table [dbo].[Tedarikciler]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tedarikciler](
	[tedarikci_id] [int] NOT NULL,
	[tedarikci_adi] [varchar](50) NOT NULL,
	[adres] [varchar](100) NULL,
	[iletisim_no] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[tedarikci_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Urunler]

-- %%
/****** Object:  Table [dbo].[Urunler]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Urunler](
	[urun_id] [int] NOT NULL,
	[urun_adi] [varchar](50) NOT NULL,
	[urun_stok] [int] NOT NULL,
	[urun_fiyat] [decimal](10, 2) NOT NULL,
	[kategori_id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[urun_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UrunTedarikci]

-- %%
/****** Object:  Table [dbo].[UrunTedarikci]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UrunTedarikci](
	[urun_tedarikci_id] [int] NOT NULL,
	[urun_id] [int] NOT NULL,
	[tedarikci_id] [int] NOT NULL,
	[tedarik_tarihi] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[urun_tedarikci_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UrunYorumlari]

-- %%
/****** Object:  Table [dbo].[UrunYorumlari]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UrunYorumlari](
	[yorum_id] [int] NOT NULL,
	[urun_id] [int] NOT NULL,
	[musteri_id] [int] NOT NULL,
	[yorum_metni] [text] NULL,
	[yorum_tarihi] [datetime] NULL,
	[puan] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[yorum_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Calisanla__ise_b__4D94879B]

-- %%
ALTER TABLE [dbo].[Calisanlar] ADD  DEFAULT (getdate()) FOR [ise_baslama_tarihi]
GO

-- %% [markdown]
-- # [DF__CalisanPe__perfo__6383C8BA]

-- %%
ALTER TABLE [dbo].[CalisanPerformansi] ADD  DEFAULT (getdate()) FOR [performans_tarihi]
GO

-- %% [markdown]
-- # [DF__IadeIslem__iade___6E01572D]

-- %%
ALTER TABLE [dbo].[IadeIslemleri] ADD  DEFAULT (getdate()) FOR [iade_tarihi]
GO

-- %% [markdown]
-- # [DF__IadeIslem__iade___6EF57B66]

-- %%
ALTER TABLE [dbo].[IadeIslemleri] ADD  DEFAULT ('Beklemede') FOR [iade_durumu]
GO

-- %% [markdown]
-- # [DF__Kargo__kargo_tar__5EBF139D]

-- %%
ALTER TABLE [dbo].[Kargo] ADD  DEFAULT (getdate()) FOR [kargo_tarih]
GO

-- %% [markdown]
-- # [DF__Musterile__kayit__45F365D3]

-- %%
ALTER TABLE [dbo].[Musteriler] ADD  DEFAULT (getdate()) FOR [kayit_tarihi]
GO

-- %% [markdown]
-- # [DF__Siparisle__sipar__5070F446]

-- %%
ALTER TABLE [dbo].[Siparisler] ADD  DEFAULT (getdate()) FOR [siparis_tarihi]
GO

-- %% [markdown]
-- # [DF__Siparisle__sipar__52593CB8]

-- %%
ALTER TABLE [dbo].[Siparisler] ADD  DEFAULT ('Beklemede') FOR [siparis_durumu]
GO

-- %% [markdown]
-- # [DF__UrunTedar__tedar__412EB0B6]

-- %%
ALTER TABLE [dbo].[UrunTedarikci] ADD  DEFAULT (getdate()) FOR [tedarik_tarihi]
GO

-- %% [markdown]
-- # [DF__UrunYorum__yorum__68487DD7]

-- %%
ALTER TABLE [dbo].[UrunYorumlari] ADD  DEFAULT (getdate()) FOR [yorum_tarihi]
GO

-- %% [markdown]
-- # [FK__Adresler__muster__48CFD27E]

-- %%
ALTER TABLE [dbo].[Adresler]  WITH CHECK ADD FOREIGN KEY([musteri_id])
REFERENCES [dbo].[Musteriler] ([musteri_id])
GO

-- %% [markdown]
-- # [FK__CalisanPe__calis__6477ECF3]

-- %%
ALTER TABLE [dbo].[CalisanPerformansi]  WITH CHECK ADD FOREIGN KEY([calisan_id])
REFERENCES [dbo].[Calisanlar] ([calisan_id])
GO

-- %% [markdown]
-- # [FK__CalisanPe__sipar__656C112C]

-- %%
ALTER TABLE [dbo].[CalisanPerformansi]  WITH CHECK ADD FOREIGN KEY([siparis_id])
REFERENCES [dbo].[Siparisler] ([siparis_id])
GO

-- %% [markdown]
-- # [FK__IadeIslem__sipar__70DDC3D8]

-- %%
ALTER TABLE [dbo].[IadeIslemleri]  WITH CHECK ADD FOREIGN KEY([siparis_id])
REFERENCES [dbo].[Siparisler] ([siparis_id])
GO

-- %% [markdown]
-- # [FK__IadeIslem__urun___71D1E811]

-- %%
ALTER TABLE [dbo].[IadeIslemleri]  WITH CHECK ADD FOREIGN KEY([urun_id])
REFERENCES [dbo].[Urunler] ([urun_id])
GO

-- %% [markdown]
-- # [FK__Kargo__siparis_i__5FB337D6]

-- %%
ALTER TABLE [dbo].[Kargo]  WITH CHECK ADD FOREIGN KEY([siparis_id])
REFERENCES [dbo].[Siparisler] ([siparis_id])
GO

-- %% [markdown]
-- # [FK__Kategori__ust_ka__37A5467C]

-- %%
ALTER TABLE [dbo].[Kategori]  WITH CHECK ADD FOREIGN KEY([ust_kategori_id])
REFERENCES [dbo].[Kategori] ([kategori_id])
GO

-- %% [markdown]
-- # [FK__SiparisDe__sipar__59FA5E80]

-- %%
ALTER TABLE [dbo].[SiparisDetay]  WITH CHECK ADD FOREIGN KEY([siparis_id])
REFERENCES [dbo].[Siparisler] ([siparis_id])
GO

-- %% [markdown]
-- # [FK__SiparisDe__urun___5AEE82B9]

-- %%
ALTER TABLE [dbo].[SiparisDetay]  WITH CHECK ADD FOREIGN KEY([urun_id])
REFERENCES [dbo].[Urunler] ([urun_id])
GO

-- %% [markdown]
-- # [FK__Siparisle__calis__5535A963]

-- %%
ALTER TABLE [dbo].[Siparisler]  WITH CHECK ADD FOREIGN KEY([calisan_id])
REFERENCES [dbo].[Calisanlar] ([calisan_id])
GO

-- %% [markdown]
-- # [FK__Siparisle__muste__5441852A]

-- %%
ALTER TABLE [dbo].[Siparisler]  WITH CHECK ADD FOREIGN KEY([musteri_id])
REFERENCES [dbo].[Musteriler] ([musteri_id])
GO

-- %% [markdown]
-- # [FK__Urunler__kategor__3C69FB99]

-- %%
ALTER TABLE [dbo].[Urunler]  WITH CHECK ADD FOREIGN KEY([kategori_id])
REFERENCES [dbo].[Kategori] ([kategori_id])
GO

-- %% [markdown]
-- # [FK__UrunTedar__tedar__4316F928]

-- %%
ALTER TABLE [dbo].[UrunTedarikci]  WITH CHECK ADD FOREIGN KEY([tedarikci_id])
REFERENCES [dbo].[Tedarikciler] ([tedarikci_id])
GO

-- %% [markdown]
-- # [FK__UrunTedar__urun___4222D4EF]

-- %%
ALTER TABLE [dbo].[UrunTedarikci]  WITH CHECK ADD FOREIGN KEY([urun_id])
REFERENCES [dbo].[Urunler] ([urun_id])
GO

-- %% [markdown]
-- # [FK__UrunYorum__muste__6B24EA82]

-- %%
ALTER TABLE [dbo].[UrunYorumlari]  WITH CHECK ADD FOREIGN KEY([musteri_id])
REFERENCES [dbo].[Musteriler] ([musteri_id])
GO

-- %% [markdown]
-- # [FK__UrunYorum__urun___6A30C649]

-- %%
ALTER TABLE [dbo].[UrunYorumlari]  WITH CHECK ADD FOREIGN KEY([urun_id])
REFERENCES [dbo].[Urunler] ([urun_id])
GO

-- %% [markdown]
-- # [CK__Calisanla__calis__4BAC3F29]

-- %%
ALTER TABLE [dbo].[Calisanlar]  WITH CHECK ADD CHECK  (([calisan_maas]>(0)))
GO

-- %% [markdown]
-- # [CK__Calisanla__komis__4CA06362]

-- %%
ALTER TABLE [dbo].[Calisanlar]  WITH CHECK ADD CHECK  (([komisyon]>=(0) AND [komisyon]<=(100)))
GO

-- %% [markdown]
-- # [CK__CalisanPe__komis__628FA481]

-- %%
ALTER TABLE [dbo].[CalisanPerformansi]  WITH CHECK ADD CHECK  (([komisyon_tutar]>=(0)))
GO

-- %% [markdown]
-- # [CK__IadeIslem__iade___6FE99F9F]

-- %%
ALTER TABLE [dbo].[IadeIslemleri]  WITH CHECK ADD CHECK  (([iade_durumu]='Tamamlandı' OR [iade_durumu]='Reddedildi' OR [iade_durumu]='Onaylandı' OR [iade_durumu]='Beklemede'))
GO

-- %% [markdown]
-- # [CK__Kargo__kargo_dur__5DCAEF64]

-- %%
ALTER TABLE [dbo].[Kargo]  WITH CHECK ADD CHECK  (([kargo_durumu]='İptal' OR [kargo_durumu]='Teslim Edildi' OR [kargo_durumu]='Gönderildi' OR [kargo_durumu]='Hazırlanıyor'))
GO

-- %% [markdown]
-- # [CK__SiparisDe__birim__59063A47]

-- %%
ALTER TABLE [dbo].[SiparisDetay]  WITH CHECK ADD CHECK  (([birim_fiyat]>(0)))
GO

-- %% [markdown]
-- # [CK__SiparisDe__urun___5812160E]

-- %%
ALTER TABLE [dbo].[SiparisDetay]  WITH CHECK ADD CHECK  (([urun_sayisi]>(0)))
GO

-- %% [markdown]
-- # [CK__Siparisle__sipar__534D60F1]

-- %%
ALTER TABLE [dbo].[Siparisler]  WITH CHECK ADD CHECK  (([siparis_durumu]='İptal' OR [siparis_durumu]='Tamamlandı' OR [siparis_durumu]='Kargoda' OR [siparis_durumu]='Hazırlanıyor' OR [siparis_durumu]='Onaylandı' OR [siparis_durumu]='Beklemede'))
GO

-- %% [markdown]
-- # [CK__Siparisle__topla__5165187F]

-- %%
ALTER TABLE [dbo].[Siparisler]  WITH CHECK ADD CHECK  (([toplam_fiyat]>=(0)))
GO

-- %% [markdown]
-- # [CK__Urunler__urun_fi__3B75D760]

-- %%
ALTER TABLE [dbo].[Urunler]  WITH CHECK ADD CHECK  (([urun_fiyat]>(0)))
GO

-- %% [markdown]
-- # [CK__Urunler__urun_st__3A81B327]

-- %%
ALTER TABLE [dbo].[Urunler]  WITH CHECK ADD CHECK  (([urun_stok]>=(0)))
GO

-- %% [markdown]
-- # [CK__UrunYoruml__puan__693CA210]

-- %%
ALTER TABLE [dbo].[UrunYorumlari]  WITH CHECK ADD CHECK  (([puan]>=(1) AND [puan]<=(5)))
GO

-- %% [markdown]
-- # [dbo].[UrunIadeIslemi]

-- %%
/****** Object:  StoredProcedure [dbo].[UrunIadeIslemi]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Ürün iade işlemini gerçekleştirir
CREATE PROCEDURE [dbo].[UrunIadeIslemi]
    @siparis_id INT,
    @urun_id INT,
    @iade_miktar INT,
    @iade_sebebi VARCHAR(100)
AS
BEGIN
    SET NOCOUNT ON;
    BEGIN TRY
        BEGIN TRANSACTION;
            -- İade talebini doğrulama
            IF NOT EXISTS (
                SELECT 1 
                FROM SiparisDetay 
                WHERE siparis_id = @siparis_id 
                AND urun_id = @urun_id
                AND urun_sayisi >= @iade_miktar
            )
                THROW 50002, 'Geçersiz iade talebi', 1;
            
            -- Stok güncelleme
            UPDATE Urunler
            SET urun_stok = urun_stok + @iade_miktar
            WHERE urun_id = @urun_id;
            
            -- İade kaydı oluşturma
            INSERT INTO IadeIslemleri (iade_id, siparis_id, urun_id, iade_sebebi)
            VALUES (NEXT VALUE FOR IadeSeq, @siparis_id, @urun_id, @iade_sebebi);
            
        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        THROW;
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[YeniSiparisEkle]

-- %%
/****** Object:  StoredProcedure [dbo].[YeniSiparisEkle]    Script Date: 5.01.2025 23:58:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- 2. SAKLI YORDAMLAR
-- Yeni sipariş ekleme işlemini gerçekleştirir
CREATE PROCEDURE [dbo].[YeniSiparisEkle]
    @musteri_id INT,
    @calisan_id INT,
    @urun_id INT,
    @urun_sayisi INT
AS
BEGIN
    SET NOCOUNT ON;
    BEGIN TRY
        BEGIN TRANSACTION;
            DECLARE @toplam_fiyat DECIMAL(10, 2);
            DECLARE @birim_fiyat DECIMAL(10, 2);
            DECLARE @mevcut_stok INT;
            
            -- Stok kontrolü ve fiyat bilgisi alma
            SELECT @mevcut_stok = urun_stok, @birim_fiyat = urun_fiyat
            FROM Urunler WITH (UPDLOCK)
            WHERE urun_id = @urun_id;
            
            IF @mevcut_stok < @urun_sayisi
                THROW 50001, 'Yetersiz stok!', 1;
            
            SET @toplam_fiyat = @birim_fiyat * @urun_sayisi;
            
            -- Sipariş oluşturma
            INSERT INTO Siparisler (musteri_id, calisan_id, toplam_fiyat)
            VALUES (@musteri_id, @calisan_id, @toplam_fiyat);
            
            DECLARE @siparis_id INT = SCOPE_IDENTITY();
            
            -- Sipariş detayı ekleme
            INSERT INTO SiparisDetay (siparis_detay_id, siparis_id, urun_id, urun_sayisi, birim_fiyat)
            VALUES (NEXT VALUE FOR SiparisDetaySeq, @siparis_id, @urun_id, @urun_sayisi, @birim_fiyat);
            
            -- Stok güncelleme
            UPDATE Urunler
            SET urun_stok = urun_stok - @urun_sayisi
            WHERE urun_id = @urun_id;
            
            -- Komisyon işleme
            INSERT INTO CalisanPerformansi (performans_id, calisan_id, siparis_id, komisyon_tutar)
            SELECT 
                NEXT VALUE FOR PerformansSeq,
                @calisan_id,
                @siparis_id,
                (@toplam_fiyat * komisyon / 100)
            FROM Calisanlar
            WHERE calisan_id = @calisan_id;
            
        COMMIT TRANSACTION;
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        THROW;
    END CATCH;
END;
GO
